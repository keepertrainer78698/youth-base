# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/matthiashugli/Downloads/s1_core_trm_player_unit_skills.csv', sep=';', header=[1,2], skiprows=[3])

# %%
df.head()
# Out:
#   Unnamed: 0_level_0       Unnamed: 1_level_0   Parent Category Id Verhalten  \
#   Unnamed: 0_level_1       Unnamed: 1_level_1        Category Name      BACK
# 0        Marco Iseli  U16 BSC YOUNG BOYS, U16  15.01.2022 09:45:00       NaN
# 1        Marco Iseli  U16 BSC YOUNG BOYS, U16  17.01.2022 17:30:00      60.0
# 2        Marco Iseli  U16 BSC YOUNG BOYS, U16  18.01.2022 17:30:00      50.0
# 3        Marco Iseli  U16 BSC YOUNG BOYS, U16  20.01.2022 17:00:00      30.0
# 4        Marco Iseli  U16 BSC YOUNG BOYS, U16  24.01.2022 17:30:00       NaN
#
#                                     DEF                                  ...  \
#   CATCH    GO  STAY Ball durch den 16er Ball in die Tiefe Distanzschuss  ...
# 0   NaN   NaN   NaN                 NaN               NaN           NaN  ...
# 1   NaN  60.0  60.0                 NaN               NaN          60.0  ...
# 2   NaN  50.0  50.0                 NaN               NaN          50.0  ...
# 3   NaN   NaN  30.0                 NaN               NaN          30.0  ...
# 4  80.0   NaN   NaN                 NaN               NaN           NaN  ...
#
#                                              OFF                       \
#   Nahdistanz RQP5er Rote Zone Spielaufbau Zone 1 Spielaufbau Zone 2/3
# 0        NaN    NaN       NaN               35.0                  NaN
# 1        NaN    NaN      60.0               60.0                  NaN
# 2        NaN    NaN      50.0               50.0                  NaN
# 3        NaN    NaN       NaN                NaN                  NaN
# 4        NaN    NaN       NaN                NaN                  NaN
#
#                             Kondition      Technik
#   Umschalten DEF-OFF Körperstabilität Ballmitnahme Dribbling Passspiel
# 0                NaN              NaN          NaN       NaN       NaN
# 1                NaN              NaN          NaN       NaN       NaN
# 2                NaN              NaN          NaN       NaN       NaN
# 3                NaN              NaN          NaN       NaN       NaN
# 4               80.0              NaN          NaN       NaN       NaN
#
# [5 rows x 21 columns]

# %%
melt_df = df.iloc[:, :17] \
            .set_index([('Unnamed: 0_level_0', 'Unnamed: 0_level_1'), ('Unnamed: 1_level_0', 'Unnamed: 1_level_1'), ('Parent Category Id', 'Category Name')])   \
                .melt(var_name=['Kategorie', 'Skill'], value_name='Dauer', ignore_index=False) \
                    .dropna(subset=['Dauer']) \
                        .reset_index()

melt_df.columns = ['Keeper', 'Team', 'DatumZeit', 'Kategorie', 'Skill', 'Dauer']

# %%
pivot_df = melt_df.pivot_table(index=['Keeper', 'Team', 'DatumZeit', 'Dauer'], columns='Kategorie', values=['Skill'], aggfunc=', '.join).reset_index()

pivot_df[('Skill', 'DEF')] = pivot_df[('Skill', 'DEF')].str.split(', ')
pivot_df[('Skill', 'OFF')] = pivot_df[('Skill', 'OFF')].str.split(', ')
pivot_df[('Skill', 'Verhalten')] = pivot_df[('Skill', 'Verhalten')].str.split(', ')

pivot_df = pivot_df.explode(('Skill', 'DEF'))
pivot_df = pivot_df.explode(('Skill', 'OFF'))
pivot_df = pivot_df.explode(('Skill', 'Verhalten'))
# pivot_df.reset_index(inplace=True)

pivot_df.columns = ['Keeper', 'Team', 'DatumZeit', 'Dauer', 'DEF', 'OFF', ' Verhalten']

pivot_df.to_csv('/Users/matthiashugli/Dropbox/⚽️ YB Nachwuchs/csv_th_skill.csv', index=False, sep=";")

# %%
#df[df.iloc[:, 0] == 'Marco Iseli']
pivot_df[pivot_df['Keeper'] == 'Yanni Rufener']
# Out:
#             Keeper                     Team            DatumZeit  Dauer  \
# 778  Yanni Rufener  U17 BSC Young Boys, U17  02.05.2022 10:15:00   45.0
# 778  Yanni Rufener  U17 BSC Young Boys, U17  02.05.2022 10:15:00   45.0
# 778  Yanni Rufener  U17 BSC Young Boys, U17  02.05.2022 10:15:00   45.0
# 779  Yanni Rufener  U17 BSC Young Boys, U17  03.02.2022 10:30:00   60.0
# 780  Yanni Rufener  U17 BSC Young Boys, U17  03.03.2022 10:30:00   60.0
# ..             ...                      ...                  ...    ...
# 833  Yanni Rufener  U17 BSC Young Boys, U17  31.03.2022 10:30:00   60.0
# 834  Yanni Rufener  U17 BSC Young Boys, U17  31.03.2022 17:30:00   35.0
# 834  Yanni Rufener  U17 BSC Young Boys, U17  31.03.2022 17:30:00   35.0
# 834  Yanni Rufener  U17 BSC Young Boys, U17  31.03.2022 17:30:00   35.0
# 835  Yanni Rufener  U17 BSC Young Boys, U17  31.05.2022 17:30:00   40.0
#
#                    DEF                   OFF  Verhalten
# 778             RQP5er                   NaN       BACK
# 778             RQP5er                   NaN      CATCH
# 778             RQP5er                   NaN       STAY
# 779                NaN    Spielaufbau Zone 1        NaN
# 780                NaN  Spielaufbau Zone 2/3        NaN
# ..                 ...                   ...        ...
# 833                NaN  Spielaufbau Zone 2/3        NaN
# 834  Ball in die Tiefe                   NaN       BACK
# 834  Ball in die Tiefe                   NaN      CATCH
# 834  Ball in die Tiefe                   NaN       STAY
# 835          Rote Zone    Spielaufbau Zone 1       STAY
#
# [136 rows x 7 columns]
