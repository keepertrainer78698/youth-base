# %%
import pandas as pd
import requests

# %%
r = requests.get('https://api.footystats.org/match?key=example&match_id=579101')

# %%
players_dict = r.json()
print(players_dict)
# Out:
# l_2': 5, 'odds_1st_half_over05': 1.52, 'odds_1st_half_over15': 3.6, 'odds_1st_half_over25': 9.25, 'odds_1st_half_over35': 21.25, 'odds_1st_half_under05': 2.39, 'odds_1st_half_under15': 1.27, 'odds_1st_half_under25': 1.03, 'odds_1st_half_under35': 1.01, 'odds_2nd_half_over05': 1.38, 'odds_2nd_half_over15': 2.25, 'odds_2nd_half_over25': 6.2, 'odds_2nd_half_over35': 13, 'odds_2nd_half_under05': 3.04, 'odds_2nd_half_under15': 1.57, 'odds_2nd_half_under25': 1.12, 'odds_2nd_half_under35': 1.02, 'odds_btts_1st_half_yes': 0, 'odds_btts_1st_half_no': 0, 'odds_btts_2nd_half_yes': 0, 'odds_btts_2nd_half_no': 0, 'overallGoalCount': 3, 'ht_goals_team_a': 3, 'ht_goals_team_b': 0, 'goals_2hg_team_a': 0, 'goals_2hg_team_b': 0, 'GoalCount_2hg': 0, 'HTGoalCount': 3, 'date_unix': 1572706800, 'winningTeam': 251, 'no_home_away': 0, 'btts_potential': 60, 'btts_fhg_potential': 20, 'btts_2hg_potential': 30, 'goalTimingDisabled': 0, 'attendance': 31131, 'corner_timings_recorded': 1, 'card_timings_recorded': 
# ...

# %%
df = pd.DataFrame(players_dict)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222 entries, current_page to odds_comparison
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   success   222 non-null    bool
#  1   pager     4 non-null      float64
#  2   metadata  1 non-null      object
#  3   data      215 non-null    object
#  4   message   222 non-null    object
# dtypes: bool(1), float64(1), object(3)
# memory usage: 8.9+ KB
# None
